# %% [markdown]
# # <center> Домашнее задание "визуализация на Python"

# %%
# Python 2 and 3 compatibility
# pip install future
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %pylab inline
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8,5
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
players = pd.read_csv('Players.csv')
print(players.shape)
# Out:
# (3922, 8)

# %%
stats = pd.read_csv('Seasons_Stats.csv') #  https://www.kaggle.com/drgilermo/nba-players-stats
print(stats.shape)
# Out:
# (24691, 53)

# %%
taxi = pd.read_csv('train.csv') # https://www.kaggle.com/c/nyc-taxi-trip-duration

# %%
players=players.dropna()

# %%
stats = stats.drop(['blanl','blank2'], axis=1)
print(stats.shape)
# Out:
# (24691, 51)

# %%
stats=stats.dropna()
print(stats.shape)
# Out:
# (14585, 51)

# %%
players['birth_state'].value_counts().head(10).plot(kind='bar') # Топ 10 штатов по количеству игроков родившихся в них

# %%
pl=players[['Player'] + ['born']].groupby('born').count()
pl.head()
# Out:
#         Player
# born
# 1915.0       1
# 1917.0       4
# 1918.0       4
# 1919.0       5
# 1920.0      14

# %%
pl.plot(kind='area') # Количество игроков родившихся в данные годы

# %%
import seaborn as sns

# %%
# Вывод зависимоси рейтинага игрока и процента реализованых 2-х очковых и 3-х очковых бросков
# %config InlineBackend.figure_format = 'png' 
sns_plot = sns.pairplot(
    stats[['PER', '2P%', '3P%']]);

# %%
taxi_df=taxi.loc[lambda x: taxi.trip_duration<7200]

# %%
sns.distplot(taxi_df.trip_duration); # Распределение времени поезки на такси (ось x ограничена искуствено для наглядности распределения)

# %%
sns.jointplot(x='PER', y='2P%',  data=stats, kind='reg'); # Корреляция рейтинга игрока от реализованых 2-х очковых бросков

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df1=stats.groupby(['Year'])['Age'].mean()

# %%
trace0 = go.Scatter(
    x=df1.index,
    y=df1,
  
)


data = [trace0]
layout = {'title': 'Средний возраст игроков на начало сезона'}

fig = go.Figure(data=data, layout=layout)

iplot(fig) #, show_link=False)
# Out:
# <div id="81ecf3f1-4278-45d5-ba9c-9aa79c3ec6d1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("81ecf3f1-4278-45d5-ba9c-9aa79c3ec6d1", [{"type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0], "y": [28.454545454545453, 26.25, 26.04794520547945, 26.02555910543131, 26.305019305019304, 26.309352517985612, 26.505084745762712, 26.39799331103679, 26.58383233532934, 26.716763005780347, 26.746630727762803, 26.936986301369863, 26.782608695652176, 26.883333333333333, 27.040871934604905, 27.206349206349206, 27.363636363636363, 27.350446428571427, 27.296803652968038, 27.50402144772118, 27.688144329896907, 27.86602870813397, 27.305, 27.0, 27.25056433408578, 27.12258064516129, 26.535796766743648, 26.630806845965772, 26.958963282937365, 26.756410256410255, 26.678571428571427, 26.663983903420522, 26.63574660633484, 26.56382978723404, 26.47590361445783, 26.54891304347826, 26.843564356435643, 26.476459510357817]}], {"title": "\u0421\u0440\u0435\u0434\u043d\u0438\u0439 \u0432\u043e\u0437\u0440\u0430\u0441\u0442 \u0438\u0433\u0440\u043e\u043a\u043e\u0432 \u043d\u0430 \u043d\u0430\u0447\u0430\u043b\u043e \u0441\u0435\u0437\u043e\u043d\u0430"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
plotly.offline.plot(fig, filename='mean_age.html', show_link=False);
